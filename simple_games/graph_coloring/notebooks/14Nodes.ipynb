# %% [markdown]
# # Using Evolution on a Known Graph

# %% [markdown]
# In this notebook, we will use our evolutionary code on a graph with a known game chromatic number.
#
# As always, we will begin with our imports

# %%
import sys
sys.path.append("../..")

# %%
from classes.genetic_algorithm import GeneticAlgorithm

# Import the rulesets and strategy
from graph_coloring.classes.gc_ruleset import GCRuleset
from graph_coloring.classes.gc_random_init_strategy import GCRandomInitStrategy

# %% [markdown]
# To begin the process, let's define the graph we are working on. An illustration of the graph is provided below.
#
# ![](../../../assets/images/14Nodes.jpg)

# %% [markdown]
# ## Setup

# %%
# Create a graph to play on
initial_state = [
    {"color": 0, "adj": [5]},
    {"color": 0, "adj": [6]},
    {"color": 0, "adj": [7]},
    {"color": 0, "adj": [8]},
    {"color": 0, "adj": [5]},
    {"color": 0, "adj": [0,4,6,10]},
    {"color": 0, "adj": [1,5,7,11]},
    {"color": 0, "adj": [2,6,8,12]},
    {"color": 0, "adj": [3,7,9,13]},
    {"color": 0, "adj": [8]},
    {"color": 0, "adj": [5]},
    {"color": 0, "adj": [6]},
    {"color": 0, "adj": [7]},
    {"color": 0, "adj": [8]},
]

# %% [markdown]
# Next, we need to create a new `GeneticAlgorithm` object. Note that the constructor for this object takes a multitude of parameters by name, so let's format it nicely for future changes.
#
# Most of the parameters, like population size and fitness, are optional. The only mandatory parameters are `ruleset`, `random_on_init_strategy`, and `strat_data`. The former is the ruleset for the game being tested. The latter two define how each member of the population receives a random strategy to play with.
#
# When creating our `ruleset`, we will set the bounds (number of colors) to 5 to start.

# %%
# Ruleset of the game being played on
ruleset = GCRuleset("Graph Coloring Ruleset", initial_state, bounds = 5)

# Create a new Evolution instance with the example strategy
gen_algo = GeneticAlgorithm(
    ruleset,
    # Random-on-initialization strategy for generating populations of random players
    random_on_init_strat = GCRandomInitStrategy,
    # Data to be used by the above strategy
    strat_data = {"vertices": range(len(ruleset.initial_state)), "colors": range(1, ruleset.bounds + 1)},
    # Size of the populations
    pop_size = 100,
    # Number of generations to iterate through
    iterations = 10,
    # Minimum number of games each player must play during a generation
    num_games = 10,
    # Starting fitness threshold
    fitness = 0.5,
    # Maximum fitness threshold; be careful of setting this too close to 1.0
    max_fitness = 0.9,
    # How much the fitness threshold should increment after each iteration
    fitness_increment = 0.025,
    # Chance of a mutation to occur during player reproduction
    mutation_rate = 0.025
)

# %% [markdown]
# Before we actually *run* the algorithm, we know that it will return two populations, so let's define a quick function to call later that will display these populations for us:

# %%
def print_pop(p1_pop, p2_pop, fitness = 0.5):
    total = len([p for p in p1_pop if p.fitness() >= fitness])
    print("Num of Player 1 with fitness above " + str(fitness) + ": " + str(total))
    for p1 in p1_pop:
        if p1.fitness() >= fitness:
            print(p1)            
    print()
    total = len([p for p in p2_pop if p.fitness() >= fitness])
    print("Num of Player 2 with fitness above " + str(fitness) + ": " + str(total))
    for p2 in p2_pop:
        if p2.fitness() >= fitness:
            print(p2)

# %% [markdown]
# ## Evolution

# %% [markdown]
# Now, all that's left is to run the `evolve()` function and watch the results!

# %%
p1_pop, p2_pop = gen_algo.evolve()

# %%
# We're only concerned with players who won an immense number of times, so we set our threshold high.
print_pop(p1_pop, p2_pop, 1.0)
# Out:
# Num of Player 1 with fitness above 1.0: 100
# Player 1: Basic Data Strategy: {'vertices': [13, 9, 1, 6, 5, 12, 3, 7, 4, 11, 10, 2, 8, 0], 'colors': [1, 4, 2, 3, 5]}
# Gen: 0 Wins: 198 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [7, 3, 0, 9, 6, 5, 12, 1, 10, 11, 13, 4, 2, 8], 'colors': [3, 4, 1, 5, 2]}
# Gen: 0 Wins: 203 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [5, 12, 3, 13, 1, 4, 6, 10, 2, 0, 9, 8, 7, 11], 'colors': [5, 1, 3, 4, 2]}
# Gen: 0 Wins: 198 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [10, 9, 7, 11, 2, 8, 6, 5, 12, 1, 4, 0, 13, 3], 'colors': [5, 4, 1, 3, 2]}
# Gen: 0 Wins: 182 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [10, 0, 6, 13, 7, 11, 8, 4, 1, 2, 9, 12, 3, 5], 'colors': [1, 4, 5, 3, 2]}
# Gen: 0 Wins: 213 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [13, 1, 5, 3, 12, 6, 0, 10, 4, 11, 9, 2, 7, 8], 'colors': [4, 5, 2, 1, 3]}
# Gen: 0 Wins: 201 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [8, 7, 11, 5, 4, 1, 12, 9, 10, 2, 6, 3, 13, 0], 'colors': [3, 1, 5, 4, 2]}
# Gen: 0 Wins: 213 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [6, 0, 13, 10, 11, 4, 2, 1, 3, 7, 9, 8, 5, 12], 'colors': [4, 5, 3, 2, 1]}
# Gen: 0 Wins: 185 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [12, 8, 0, 10, 4, 5, 13, 7, 3, 2, 11, 1, 6, 9], 'colors': [2, 1, 5, 4, 3]}
# Gen: 0 Wins: 197 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [4, 7, 5, 12, 0, 6, 2, 13, 3, 8, 9, 11, 10, 1], 'colors': [4, 3, 2, 5, 1]}
# Gen: 0 Wins: 187 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [9, 11, 8, 12, 10, 4, 2, 3, 0, 5, 7, 6, 1, 13], 'colors': [4, 2, 5, 3, 1]}
# Gen: 0 Wins: 198 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [8, 2, 9, 4, 6, 1, 3, 10, 11, 0, 5, 13, 7, 12], 'colors': [5, 1, 3, 2, 4]}
# Gen: 0 Wins: 213 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [9, 10, 12, 1, 4, 2, 7, 6, 8, 0, 13, 3, 11, 5], 'colors': [1, 5, 4, 3, 2]}
# Gen: 0 Wins: 203 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [5, 3, 12, 2, 4, 10, 13, 0, 6, 11, 7, 9, 8, 1], 'colors': [2, 4, 3, 1, 5]}
# Gen: 0 Wins: 197 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [0, 4, 6, 8, 1, 11, 5, 12, 13, 10, 3, 7, 9, 2], 'colors': [5, 3, 2, 1, 4]}
# Gen: 0 Wins: 215 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [0, 13, 2, 7, 9, 11, 8, 6, 10, 4, 12, 3, 1, 5], 'colors': [1, 4, 5, 2, 3]}
# Gen: 0 Wins: 203 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [4, 10, 13, 1, 0, 12, 3, 7, 2, 11, 9, 6, 5, 8], 'colors': [1, 3, 2, 4, 5]}
# Gen: 0 Wins: 217 Losses: 0
# Player 1: Basic Data Strategy: {'vertices':
Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [8, 3, 11, 0, 10, 2, 7, 4, 9, 1, 13, 5, 6, 12], 'colors': [3, 1, 2, 5, 4]}
# Gen: 0 Wins: 203 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [1, 5, 7, 3, 2, 13, 10, 9, 0, 6, 4, 8, 11, 12], 'colors': [2, 4, 5, 3, 1]}
# Gen: 0 Wins: 186 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [10, 3, 7, 11, 13, 1, 6, 2, 4, 5, 9, 12, 0, 8], 'colors': [3, 1, 2, 4, 5]}
# Gen: 0 Wins: 214 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [13, 12, 5, 11, 0, 9, 3, 10, 2, 4, 1, 8, 7, 6], 'colors': [4, 3, 1, 5, 2]}
# Gen: 0 Wins: 191 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [7, 13, 0, 2, 5, 6, 9, 11, 3, 12, 8, 4, 1, 10], 'colors': [3, 4, 2, 5, 1]}
# Gen: 0 Wins: 209 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [6, 12, 2, 9, 3, 10, 5, 13, 1, 0, 8, 11, 7, 4], 'colors': [4, 3, 2, 1, 5]}
# Gen: 0 Wins: 218 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [8, 12, 0, 10, 6, 1, 11, 7, 5, 13, 3, 9, 2, 4], 'colors': [3, 4, 1, 2, 5]}
# Gen: 0 Wins: 196 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [6, 12, 3, 5, 13, 4, 0, 9, 1, 8, 10, 11, 2, 7], 'colors': [3, 5, 1, 4, 2]}
# Gen: 0 Wins: 201 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [2, 10, 9, 0, 13, 5, 7, 11, 12, 4, 6, 1, 8, 3], 'colors': [3, 4, 2, 5, 1]}
# Gen: 0 Wins: 198 Losses: 0
#
# Num of Player 2 with fitness above 1.0: 0

# %% [markdown]
# It seems our Player 1 population is doing very well with 3 colors. Many players have discovered strategies that have caused them to win 100% of the games they play.

# %% [markdown]
# ## Decreasing the Bounds

# %% [markdown]
# Let's try this again, but decrease the number of colors available to 4.

# %%
# Ruleset of the game being played on
ruleset = GCRuleset("Graph Coloring Ruleset", initial_state, bounds = 4)

# Create a new Evolution instance with the example strategy
gen_algo = GeneticAlgorithm(
    ruleset,
    # Random-on-initialization strategy for generating populations of random players
    random_on_init_strat = GCRandomInitStrategy,
    # Data to be used by the above strategy
    strat_data = {"vertices": range(len(ruleset.initial_state)), "colors": range(1, ruleset.bounds + 1)},
    # Size of the populations
    pop_size = 100,
    # Number of generations to iterate through
    iterations = 10,
    # Minimum number of games each player must play during a generation
    num_games = 10,
    # Starting fitness threshold
    fitness = 0.5,
    # Maximum fitness threshold; be careful of setting this too close to 1.0
    max_fitness = 0.9,
    # How much the fitness threshold should increment after each iteration
    fitness_increment = 0.025,
    # Chance of a mutation to occur during player reproduction
    mutation_rate = 0.025
)
p1_pop, p2_pop = gen_algo.evolve()

# %%
# We're only concerned with players who won an immense number of times, so we set our threshold high.
print_pop(p1_pop, p2_pop, 1.0)
# Out:
# Num of Player 1 with fitness above 1.0: 55
# Player 1: Basic Data Strategy: {'vertices': [3, 7, 4, 11, 1, 5, 2, 12, 13, 10, 8, 6, 0, 9], 'colors': [1, 4, 3, 2]}
# Gen: 0 Wins: 203 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [0, 10, 8, 2, 7, 5, 3, 9, 6, 12, 11, 13, 4, 1], 'colors': [3, 1, 4, 2]}
# Gen: 0 Wins: 200 Losses: 0
# Player 1: Basic Data Strategy: {'vertices':
Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [13, 6, 10, 9, 1, 4, 5, 11, 8, 3, 0, 7, 12, 2], 'colors': [2, 4, 3, 1]}
# Gen: 0 Wins: 210 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [3, 5, 12, 13, 7, 11, 1, 4, 9, 10, 8, 0, 2, 6], 'colors': [3, 1, 2, 4]}
# Gen: 0 Wins: 185 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [4, 8, 9, 13, 10, 6, 3, 0, 1, 2, 5, 7, 12, 11], 'colors': [3, 2, 4, 1]}
# Gen: 0 Wins: 210 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [7, 13, 5, 8, 1, 11, 4, 2, 9, 6, 0, 12, 3, 10], 'colors': [1, 2, 4, 3]}
# Gen: 0 Wins: 206 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [1, 11, 10, 5, 13, 7, 9, 6, 8, 4, 3, 2, 0, 12], 'colors': [3, 1, 4, 2]}
# Gen: 0 Wins: 217 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [5, 7, 0, 2, 4, 10, 13, 8, 11, 9, 1, 6, 12, 3], 'colors': [2, 3, 1, 4]}
# Gen: 0 Wins: 203 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [7, 13, 1, 9, 4, 6, 12, 10, 0, 2, 5, 8, 11, 3], 'colors': [3, 1, 2, 4]}
# Gen: 0 Wins: 197 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [8, 5, 10, 11, 9, 6, 13, 7, 0, 2, 4, 1, 12, 3], 'colors': [4, 2, 1, 3]}
# Gen: 0 Wins: 210 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [12, 7, 8, 4, 6, 10, 13, 11, 0, 5, 9, 2, 1, 3], 'colors': [3, 1, 4, 2]}
# Gen: 0 Wins: 197 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [6, 13, 11, 3, 5, 2, 9, 1, 7, 4, 0, 10, 8, 12], 'colors': [3, 2, 4, 1]}
# Gen: 0 Wins: 203 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [1, 7, 6, 8, 3, 4, 13, 2, 12, 11, 9, 10, 5, 0], 'colors': [1, 3, 4, 2]}
# Gen: 0 Wins: 188 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [6, 1, 8, 9, 2, 13, 7, 11, 3, 0, 10, 5, 12, 4], 'colors': [3, 2, 1, 4]}
# Gen: 0 Wins: 207 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [9, 11, 2, 4, 12, 0, 1, 13, 6, 7, 10, 5, 3, 8], 'colors': [3, 2, 1, 4]}
# Gen: 0 Wins: 201 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [7, 2, 11, 12, 4, 3, 5, 6, 8, 13, 1, 0, 10, 9], 'colors': [3, 1, 4, 2]}
# Gen: 0 Wins: 191 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [5, 2, 10, 6, 4, 3, 11, 9, 7, 8, 0, 1, 12, 13], 'colors': [2, 3, 4, 1]}
# Gen: 0 Wins: 195 Losses: 0
#
# Num of Player 2 with fitness above 1.0: 0

# %% [markdown]
# We still have a strong Player 1 population. Let's lower the bounds once more to 3.

# %%
# Ruleset of the game being played on
ruleset = GCRuleset("Graph Coloring Ruleset", initial_state, bounds = 3)

# Create a new Evolution instance with the example strategy
gen_algo = GeneticAlgorithm(
    ruleset,
    # Random-on-initialization strategy for generating populations of random players
    random_on_init_strat = GCRandomInitStrategy,
    # Data to be used by the above strategy
    strat_data = {"vertices": range(len(ruleset.initial_state)), "colors": range(1, ruleset.bounds + 1)},
    # Size of the populations
    pop_size = 100,
    # Number of generations to iterate through
    iterations = 10,
    # Minimum number of games each player must play during a generation
    num_games = 10,
    # Starting fitness threshold
    fitness = 0.5,
    # Maximum fitness threshold; be careful of setting this too close to 1.0
    max_fitness = 0.9,
    # How much the fitness threshold should increment after each iteration
    fitness_increment = 0.025,
    # Chance of a mutation to occur during player reproduction
    mutation_rate = 0.025
)
p1_pop, p2_pop = gen_algo.evolve()

# %%
# We're only concerned with players who won an immense number of times, so we set our threshold high.
print_pop(p1_pop, p2_pop, 1.0)
# Out:
# Num of Player 1 with fitness above 1.0: 15
# Player 1: Basic Data Strategy: {'vertices': [6, 4, 12, 7, 8, 0, 10, 2, 13, 11, 1, 3, 5, 9], 'colors': [3, 1, 2]}
# Gen: 0 Wins: 203 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [6, 8, 3, 9, 11, 1, 4, 0, 13, 10, 7, 5, 12, 2], 'colors': [3, 1, 2]}
# Gen: 0 Wins: 196 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [8, 6, 7, 10, 13, 12, 1, 3, 4, 0, 5, 9, 2, 11], 'colors': [1, 2, 3]}
# Gen: 0 Wins: 214 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [8, 2, 6, 9, 10, 1, 12, 3, 13, 7, 11, 5, 0, 4], 'colors': [3, 1, 2]}
# Gen: 0 Wins: 193 Losses: 0
# Player 1: Basic Data Strategy: {'vertices': [6, 1, 12, 8, 5, 3, 7, 4, 2, 9, 13, 0, 11, 10], 'colors': [1, 2, 3]}
# Gen: 0 Wins: 187 Losses: 0
# Player 1 #1.7: Evolved Strategy #7: {'vertices': [6, 8, 3, 7, 13, 2, 5, 1, 11, 12, 10, 0, 4, 9], 'colors': [3, 1, 2]}
# Gen: 1 Wins: 162 Losses: 0
# Player 1 #1.22: Evolved Strategy #22: {'vertices': [6, 8, 10, 12, 0, 1, 9, 11, 13, 3, 2, 7, 5, 4], 'colors': [3, 1, 2]}
# Gen: 2 Wins: 154 Losses: 0
# Player 1 #2.21: Evolved Strategy #21: {'vertices': [6, 1, 12, 8, 5, 3, 7, 4, 2, 9, 11, 0, 13, 10], 'colors': [3, 1, 2]}
# Gen: 2 Wins: 144 Losses: 0
# Player 1 #2.26: Evolved Strategy #26: {'vertices': [13, 1, 5, 7, 0, 12, 11, 8, 4, 10, 2, 6, 9, 3], 'colors': [1, 3, 2]}
# Gen: 2 Wins: 130 Losses: 0
# Player 1 #3.6: Evolved Strategy #6: {'vertices': [6, 8, 2, 9, 10, 1, 12, 3, 13, 7, 11, 5, 0, 4], 'colors': [1, 2, 3]}
# Gen: 3 Wins: 118 Losses: 0
# Player 1 #4.15: Evolved Strategy #15: {'vertices': [6, 8, 3, 7, 13, 2, 5, 1, 9, 4, 11, 10, 12, 0], 'colors': [3, 1, 2]}
# Gen: 3 Wins: 96 Losses: 0
# Player 1 #6.1: Evolved Strategy #1: {'vertices': [6, 8, 3, 7, 1, 5, 9, 11, 13, 10, 4, 0, 12, 2], 'colors': [2, 3, 1]}
# Gen: 6 Wins: 55 Losses: 0
# Player 1 #7.2: Evolved Strategy #2: {'vertices': [7, 1, 9, 5, 0, 6, 11, 4, 13, 2, 12, 10, 8, 3], 'colors': [3, 1, 2]}
# Gen: 6 Wins: 43 Losses: 0
# Player 1 #7.3: Evolved Strategy #3: {'vertices': [6, 1, 12, 8, 5, 3, 7, 4, 2, 9, 10, 11, 13, 0], 'colors': [1, 2, 3]}
# Gen: 5 Wins: 34 Losses: 0
# Player 1 #8.5: Evolved Strategy #5: {'vertices': [5, 3, 13, 10, 8, 4, 7, 2, 1, 11, 12, 6, 0, 9], 'colors': [2, 1, 3]}
# Gen: 2 Wins: 15 Losses: 0
#
# Num of Player 2 with fitness above 1.0: 0

# %% [markdown]
# Impressive! We *still* have a Player 1 population with only 3 colors. Out of curiosity, let's test on 2.

# %%
# Ruleset of the game being played on
ruleset = GCRuleset("Graph Coloring Ruleset", initial_state, bounds = 2)

# Create a new Evolution instance with the example strategy
gen_algo = GeneticAlgorithm(
    ruleset,
    # Random-on-initialization strategy for generating populations of random players
    random_on_init_strat = GCRandomInitStrategy,
    # Data to be used by the above strategy
    strat_data = {"vertices": range(len(ruleset.initial_state)), "colors": range(1, ruleset.bounds + 1)},
    # Size of the populations
    pop_size = 100,
    # Number of generations to iterate through
    iterations = 10,
    # Minimum number of games each player must play during a generation
    num_games = 10,
    # Starting fitness threshold
    fitness = 0.5,
    # Maximum fitness threshold; be careful of setting this too close to 1.0
    max_fitness = 0.9,
    # How much the fitness threshold should increment after each iteration
    fitness_increment = 0.025,
    # Chance of a mutation to occur during player reproduction
    mutation_rate = 0.025
)
p1_pop, p2_pop = gen_algo.evolve()

# %%
# We're only concerned with players who won an immense number of times, so we set our threshold high.
print_pop(p1_pop, p2_pop, 0.95)
# Out:
# Num of Player 1 with fitness above 0.95: 0
#
# Num of Player 2 with fitness above 0.95: 51
# Player 2: Basic Data Strategy: {'vertices': [4, 11, 9, 12, 2, 13, 10, 5, 7, 1, 6, 8, 0, 3], 'colors': [2, 1]}
# Gen: 0 Wins: 201 Losses: 0
# Player 2: Basic Data Strategy: {'vertices': [13, 4, 2, 7, 3, 9, 11, 1, 8, 6, 5, 10, 0, 12], 'colors': [2, 1]}
# Gen: 0 Wins: 224 Losses: 1
# Player 2: Basic Data Strategy: {'vertices': [3, 1, 12, 10, 7, 2, 0, 4, 13, 6, 5, 9, 8, 11], 'colors': [2, 1]}
# Gen: 0 Wins: 200 Losses: 1
# Player 2: Basic Data Strategy: {'vertices': [0, 9, 1, 12, 11, 2, 5, 6, 8, 4, 13, 7, 3, 10], 'colors': [2, 1]}
# Gen: 0 Wins: 197 Losses: 1
# Player 2: Basic Data Strategy: {'vertices': [4, 13, 11, 0, 10, 5, 2, 12, 1, 3, 6, 9, 8, 7], 'colors': [2, 1]}
# Gen: 0 Wins: 196 Losses: 2
# Player 2: Basic Data Strategy: {'vertices': [10, 1, 2, 5, 11, 13, 9, 6, 7, 3, 0, 8, 12, 4], 'colors': [1, 2]}
# Gen: 0 Wins: 195 Losses: 2
# Player 2: Basic Data Strategy: {'vertices': [12, 0, 9, 1, 7, 6, 3, 5, 8, 13, 2, 10, 4, 11], 'colors': [2, 1]}
# Gen: 0 Wins: 191 Losses: 2
# Player 2: Basic Data Strategy: {'vertices': [1, 0, 12, 13, 4, 9, 2, 8, 11, 3, 10, 7, 5, 6], 'colors': [1, 2]}
# Gen: 0 Wins: 184 Losses: 2
# Player 2: Basic Data Strategy: {'vertices': [3, 1, 0, 5, 7, 2, 8, 13, 4, 12, 9, 10, 6, 11], 'colors': [1, 2]}
# Gen: 0 Wins: 200 Losses: 3
# Player 2: Basic Data Strategy: {'vertices': [3, 12, 9, 11, 13, 7, 1, 8, 0, 6, 10, 5, 2, 4], 'colors': [2, 1]}
# Gen: 0 Wins: 191 Losses: 3
# Player 2: Basic Data Strategy: {'vertices': [10, 1, 7, 9, 13, 6, 11, 3, 8, 2, 5, 0, 12, 4], 'colors': [1, 2]}
# Gen: 0 Wins: 210 Losses: 4
# Player 2: Basic Data Strategy: {'vertices': [2, 9, 13, 10, 1, 11, 7, 4, 6, 3, 5, 8, 12, 0], 'colors': [2, 1]}
# Gen: 0 Wins: 208 Losses: 4
# Player 2: Basic Data Strategy: {'vertices': [0, 9, 1, 8, 4, 10, 5, 3, 13, 12, 7, 6, 11, 2], 'colors': [2, 1]}
# Gen: 0 Wins: 188 Losses: 4
# Player 2: Basic Data Strategy: {'vertices': [0, 4, 13, 9, 5, 8, 12, 10, 1, 11, 7, 2, 3, 6], 'colors': [2, 1]}
# Gen: 0 Wins: 186 Losses: 4
# Player 2: Basic Data Strategy: {'vertices': [1, 12, 9, 10, 11, 6, 7, 8, 0, 4, 13, 3, 5, 2], 'colors': [1, 2]}
# Gen: 0 Wins: 179 Losses: 4
# Player 2: Basic Data Strategy: {'vertices': [12, 5, 13, 9, 1, 0, 2, 3, 7, 4, 8, 6, 11, 10], 'colors': [2, 1]}
# Gen: 0 Wins: 210 Losses: 5
# Player 2: Basic Data Strategy: {'vertices': [3, 12, 11, 6, 0, 8, 2, 1, 5, 7, 4, 9, 13, 10], 'colors': [2, 1]}
# Gen: 0 Wins: 207 Losses: 5
# Player 2: Basic Data Strategy: {'vertices': [10, 2, 7, 9, 1, 4, 8, 6, 0, 3, 12, 5, 13, 11], 'colors': [2, 1]}
# Gen: 0 Wins: 198 Losses: 5
# Player 2: Basic Data Strategy: {'vertices': [9, 10, 1, 4, 6, 3, 5, 0, 8, 13, 2, 12, 7, 11], 'colors': [2, 1]}
# Gen: 0 Wins: 190 Losses: 5
# Player 2: Basic Data Strategy: {'vertices': [13, 8, 12, 10, 2, 5, 6, 7, 0, 3, 4, 1, 11, 9], 'colors': [1, 2]}
# Gen: 0 Wins: 188 Losses: 5
# Player 2: Basic Data Strategy: {'vertices': [9, 10, 13, 6, 3, 11, 8, 12, 4, 2, 1, 0, 7, 5], 'colors': [2, 1]}
# Gen: 0 Wins: 186 Losses: 5
# Player 2: Basic Data Strategy: {'vertices': [2, 9, 5, 4, 0, 13, 10, 3, 11, 7, 6, 1, 8, 12], 'colors': [2, 1]}
# Gen: 0 Wins: 184 Losses: 5
# Player 2: Basic Data Strategy: {'vertices': [2, 9, 4, 13, 8, 10, 11, 0, 1, 3, 5, 12, 6, 7], 'colors': [1, 2]}
# Gen: 0 Wins: 183 Losses: 5
# Player 2: Basic Data Strategy: {'vertices': [1, 6, 4, 11, 8, 12, 2, 7, 9, 5, 13, 3, 0, 10], 'colors': [2, 1]}
# Gen: 0 Wins: 207 Losses: 6
# Player 2: Basic Data Strategy: {'vertices': [1, 12, 8, 10, 3, 2, 4, 11, 9, 7, 13, 5, 6, 0], 'colors': [1, 2]}
# Gen: 0 Wins: 203 Losses: 6
# Player 2: Basic Data Strategy: {'vertices': [1, 10, 12, 5, 4, 7, 0, 13, 2, 9, 3, 8, 6, 11], 'colors': [1, 2]}
# Gen: 0 Wins: 167 Losses: 5
# Player 2: Basic Data Strategy: {'vertices': [4, 13, 7, 3, 0, 6, 10, 8, 12, 2, 9, 5, 11, 1], 'colors': [1, 2]}
# Gen: 0 Wins: 200 Losses: 6
# Player 2: Basic Data Strategy: {'vertices': [9, 10, 11, 8, 4, 3, 2, 7, 12, 6, 5, 0, 13, 1], 'colors': [1, 2]}
# Gen: 0 Wins: 200 Losses: 6
# Player 2: Basic Data Strategy: {'vertices': [13, 3, 10, 4, 6, 7, 0, 11, 8, 1, 5, 2, 9, 12], 'colors': [2, 1]}
# Gen: 0 Wins: 199 Losses: 6
# Player 2: Basic Data Strategy: {'vertices': [0, 2, 13, 7, 1, 8, 4, 10, 11, 12, 3, 9, 5, 6], 'colors': [1, 2]}
# Gen: 0 Wins: 199 Losses: 6
# Player 2: Basic Data Strategy: {'vertices': [2, 11, 8, 9, 0, 3, 6, 13, 4, 1, 5, 12, 10, 7], 'colors': [2, 1]}
# Gen: 0 Wins: 196 Losses: 6
# Player 2: Basic Data Strategy: {'vertices': [2, 3, 1, 10, 8, 12, 4, 0, 13, 7, 9, 5, 6, 11], 'colors': [1, 2]}
# Gen: 0 Wins: 193 Losses: 6
# Player 2: Basic Data Strategy: {'vertices': [10, 13, 9, 2, 0, 7, 6, 5, 8, 11, 4, 12, 3, 1], 'colors': [2, 1]}
# Gen: 0 Wins: 186 Losses: 6
# Player 2: Basic Data Strategy: {'vertices': [0, 1, 4, 10, 5, 11, 8, 9, 7, 12, 13, 3, 6, 2], 'colors': [2, 1]}
# Gen: 0 Wins: 180 Losses: 6
# Player 2: Basic Data Strategy: {'vertices': [13, 12, 2, 6, 8, 11, 1, 5, 4, 0, 7, 3, 10, 9], 'colors': [2, 1]}
# Gen: 0 Wins: 204 Losses: 7
# Player 2: Basic Data Strategy: {'vertices': [3, 6, 10, 5, 2, 1, 13, 4, 0, 9, 12, 11, 8, 7], 'colors': [2, 1]}
# Gen: 0 Wins: 195 Losses: 7
# Player 2: Basic Data Strategy: {'vertices': [3, 8, 11, 10, 12, 6, 2, 5, 13, 1, 4, 9, 7, 0], 'colors': [1, 2]}
# Gen: 0 Wins: 194 Losses: 7
# Player 2: Basic Data Strategy: {'vertices': [4, 10, 9, 2, 3, 7, 6, 0, 8, 11, 1, 13, 12, 5], 'colors': [2, 1]}
# Gen: 0 Wins: 193 Losses: 7
# Player 2: Basic Data Strategy: {'vertices': [9, 1, 0, 13, 12, 2, 8, 5, 4, 10, 7, 11, 6, 3], 'colors': [2, 1]}
# Gen: 0 Wins: 217 Losses: 8
# Player 2: Basic Data Strategy: {'vertices': [12, 9, 10, 4, 13, 1, 7, 3, 5, 2, 6, 8, 11, 0], 'colors': [1, 2]}
# Gen: 0 Wins: 186 Losses: 7
# Player 2: Basic Data Strategy: {'vertices': [2, 12, 9, 4, 3, 8, 5, 1, 6, 7, 0, 13, 11, 10], 'colors': [1, 2]}
# Gen: 0 Wins: 176 Losses: 7
# Player 2: Basic Data Strategy: {'vertices': [5, 2, 3, 1, 11, 12, 8, 7, 10, 13, 6, 9, 0, 4], 'colors': [2, 1]}
# Gen: 0 Wins: 186 Losses: 8
# Player 2: Basic Data Strategy: {'vertices': [0, 13, 4, 3, 7, 2, 8, 12, 9, 10, 1, 5, 11, 6], 'colors': [2, 1]}
# Gen: 0 Wins: 185 Losses: 8
# Player 2: Basic Data Strategy: {'vertices': [2, 10, 1, 12, 11, 8, 13, 6, 9, 7, 5, 4, 0, 3], 'colors': [2, 1]}
# Gen: 0 Wins: 183 Losses: 8
# Player 2: Basic Data Strategy: {'vertices': [9, 6, 1, 11, 10, 2, 7, 12, 13, 5, 4, 3, 0, 8], 'colors': [1, 2]}
# Gen: 0 Wins: 205 Losses: 9
# Player 2: Basic Data Strategy: {'vertices': [3, 12, 6, 9, 11, 5, 2, 7, 8, 10, 0, 1, 13, 4], 'colors': [1, 2]}
# Gen: 0 Wins: 200 Losses: 9
# Player 2: Basic Data Strategy: {'vertices': [11, 4, 7, 10, 5, 8, 3, 1, 13, 2, 12, 0, 6, 9], 'colors': [1, 2]}
# Gen: 0 Wins: 200 Losses: 9
# Player 2: Basic Data Strategy: {'vertices': [4, 3, 2, 6, 10, 7, 12, 0, 11, 9, 5, 1, 13, 8], 'colors': [1, 2]}
# Gen: 0 Wins: 200 Losses: 9
# Player 2: Basic Data Strategy: {'vertices': [11, 9, 7, 4, 0, 8, 12, 6, 1, 13, 3, 2, 5, 10], 'colors': [1, 2]}
# Gen: 0 Wins: 195 Losses: 10
# Player 2: Basic Data Strategy: {'vertices': [12, 7, 11, 1, 6, 8, 0, 5, 2, 3, 4, 9, 13, 10], 'colors': [1, 2]}
# Gen: 0 Wins: 195 Losses: 10
# Player 2: Basic Data Strategy: {'vertices': [13, 10, 8, 6, 0, 3, 2, 1, 4, 5, 9, 11, 12, 7], 'colors': [1, 2]}
# Gen: 0 Wins: 171 Losses: 9

# %% [markdown]
# These results are expected. While it is *possible* for Player 1 to win with two colors, it is *highly* unlikely, and it comes as no surprise that our Player 1 population is abysmally low.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# It appears that we have discovered viable strategies for this graph on 3 colors.
