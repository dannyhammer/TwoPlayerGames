# %% [markdown]
# # Graph Coloring Evolution

# %% [markdown]
# In this notebook, we will demonstrate how to use our provided evolutionary code on the graph coloring game.
#
# As always, we will begin with our imports

# %%
import sys
sys.path.append("../..")

# %%
from classes.genetic_algorithm import GeneticAlgorithm

# Import the rulesets and strategy
from graph_coloring.classes.gc_ruleset import GCRuleset
from graph_coloring.classes.gc_random_init_strategy import GCRandomInitStrategy

# %% [markdown]
# To begin the process, we need a game ruleset and an example strategy. The ruleset is used to define how each game will be played, and the strategy is used as a reference when generating populations of players.

# %%
# Create a graph to play on
initial_state = [
    {"color": 0, "adj": [1, 2]},
    {"color": 0, "adj": [0, 2, 3]},
    {"color": 0, "adj": [0, 1, 3, 6]},
    {"color": 0, "adj": [1, 2, 5]},
    {"color": 0, "adj": [5]},
    {"color": 0, "adj": [3, 4, 9]},
    {"color": 0, "adj": [2, 7, 9]},
    {"color": 0, "adj": [6, 8, 9]},
    {"color": 0, "adj": [7]},
    {"color": 0, "adj": [6, 7, 10]},
    {"color": 0, "adj": [9]},
]

# Create our ruleset and strategy using the graph and bounds
ruleset =  GCRuleset("Graph Coloring Ruleset", initial_state, bounds=3)

strat_data = {"vertices": range(len(ruleset.initial_state)), "colors": range(1, ruleset.bounds + 1)}

# %% [markdown]
# Next, we need to create a new `Evolution` object and pass in our example strategy to its constructor. This allows the object to create populations of random players with valid and unique strategies.
#
# We could add more parameters to our `Evolution` object, but we will discuss those later.

# %%
# Create a new Evolution instance with the example strategy
gen_algo = GeneticAlgorithm(
    ruleset,
    GCRandomInitStrategy,
    strat_data,
    pop_size = 100,
    iterations = 10,
    num_games = 10,
    fitness = 0.5,
    max_fitness = 0.9,
    fitness_increment = 0.025,
    mutation_rate = 0.025
)

# %% [markdown]
# Now, all that's left is to run the `evolve()` function and watch the results!

# %%
p1_pop, p2_pop = gen_algo.evolve(verbose=True)
# Out:
# ITERATION: 0, FITNESS: 0.5
# 	P1 Pop: 63
# 	P2 Pop: 43
#
# ITERATION: 1, FITNESS: 0.525
# 	P1 Pop: 57
# 	P2 Pop: 45
#
# ITERATION: 2, FITNESS: 0.55
# 	P1 Pop: 59
# 	P2 Pop: 49
#
# ITERATION: 3, FITNESS: 0.575
# 	P1 Pop: 39
# 	P2 Pop: 63
#
# ITERATION: 4, FITNESS: 0.6
# 	P1 Pop: 37
# 	P2 Pop: 43
#
# ITERATION: 5, FITNESS: 0.625
# 	P1 Pop: 29
# 	P2 Pop: 40
#
# ITERATION: 6, FITNESS: 0.65
# 	P1 Pop: 13
# 	P2 Pop: 65
#
# ITERATION: 7, FITNESS: 0.675
# 	P1 Pop: 8
# 	P2 Pop: 63
#
# ITERATION: 8, FITNESS: 0.7
# 	P1 Pop: 1
# 	P2 Pop: 75
# WARNING: Player 1 population too low! Repopulating randomly
#
# ITERATION: 9, FITNESS: 0.725
# 	P1 Pop: 19
# 	P2 Pop: 75

# %% [markdown]
# Now that all iterations have been run, we can view each member of the remaining populations with a simple loop.

# %%
for p1 in p1_pop:
    if p1.fitness() > 0.5:
        print(p1)
print()
for p2 in p2_pop:
    if p2.fitness() > 0.5:
        print(p2)
# Out:
# Player 1 #8.17: Evolved Strategy #17: {'vertices': [5, 4, 10, 1, 7, 6, 0, 2, 8, 9, 3], 'colors': [1, 2, 3]}
# Gen: 1 Wins: 20 Losses: 1
# Player 1: Basic Data Strategy: {'vertices': [5, 4, 10, 1, 7, 6, 0, 3, 2, 9, 8], 'colors': [1, 3, 2]}
# Gen: 0 Wins: 19 Losses: 1
# Player 1 #8.8: Evolved Strategy #8: {'vertices': [5, 2, 0, 1, 3, 9, 10, 7, 8, 6, 4], 'colors': [1, 3, 2]}
# Gen: 1 Wins: 15 Losses: 1
# Player 1 #8.2: Evolved Strategy #2: {'vertices': [4, 3, 6, 5, 10, 2, 7, 8, 0, 9, 1], 'colors': [3, 2, 1]}
# Gen: 1 Wins: 16 Losses: 2
# Player 1: Basic Data Strategy: {'vertices': [3, 6, 4, 1, 2, 0, 8, 9, 10, 7, 5], 'colors': [3, 1, 2]}
# Gen: 0 Wins: 14 Losses: 2
# Player 1 #8.3: Evolved Strategy #3: {'vertices': [1, 5, 2, 4, 10, 8, 7, 9, 6, 3, 0], 'colors': [1, 3, 2]}
# Gen: 1 Wins: 19 Losses: 3
# Player 1 #8.42: Evolved Strategy #42: {'vertices': [4, 3, 6, 5, 10, 2, 7, 8, 0, 1, 9], 'colors': [3, 2, 1]}
# Gen: 4 Wins: 19 Losses: 3
# Player 1 #8.7: Evolved Strategy #7: {'vertices': [4, 3, 6, 5, 10, 2, 7, 8, 0, 9, 1], 'colors': [3, 2, 1]}
# Gen: 2 Wins: 16 Losses: 3
# Player 1 #8.30: Evolved Strategy #30: {'vertices': [1, 6, 8, 2, 3, 4, 0, 10, 5, 7, 9], 'colors': [3, 2, 1]}
# Gen: 2 Wins: 16 Losses: 3
# Player 1: Basic Data Strategy: {'vertices': [5, 2, 4, 8, 9, 7, 10, 1, 0, 6, 3], 'colors': [2, 3, 1]}
# Gen: 0 Wins: 10 Losses: 2
# Player 1: Basic Data Strategy: {'vertices': [5, 2, 0, 4, 1, 7, 6, 9, 8, 10, 3], 'colors': [2, 3, 1]}
# Gen: 0 Wins: 20 Losses: 4
# Player 1 #8.45: Evolved Strategy #45: {'vertices': [9, 5, 8, 6, 0, 3, 4, 2, 7, 10, 1], 'colors': [3, 2, 1]}
# Gen: 5 Wins: 23 Losses: 5
# Player 1: Basic Data Strategy: {'vertices': [3, 1, 5, 0, 8, 2, 6, 4, 7, 10, 9], 'colors': [3, 1, 2]}
# Gen: 0 Wins: 17 Losses: 4
# Player 1 #8.39: Evolved Strategy #39: {'vertices': [9, 4, 6, 1, 0, 10, 3, 2, 8, 5, 7], 'colors': [3, 1, 2]}
# Gen: 1 Wins: 20 Losses: 5
# Player 1: Basic Data Strategy: {'vertices': [4, 3, 6, 5, 10, 2, 7, 8, 1, 0, 9], 'colors': [3, 1, 2]}
# Gen: 0 Wins: 15 Losses: 4
# Player 1: Basic Data Strategy: {'vertices': [5, 2, 1, 3, 4, 8, 0, 6, 10, 9, 7], 'colors': [2, 1, 3]}
# Gen: 0 Wins: 11 Losses: 3
# Player 1: Basic Data Strategy: {'vertices': [1, 5, 2, 4, 7, 8, 0, 9, 6, 10, 3], 'colors': [1, 3, 2]}
# Gen: 0 Wins: 14 Losses: 4
# Player 1 #8.18: Evolved Strategy #18: {'vertices': [9, 8, 6, 3, 7, 2, 1, 10, 4, 5, 0], 'colors': [3, 1, 2]}
# Gen: 1 Wins: 14 Losses: 5
# Player 1 #8.24: Evolved Strategy #24: {'vertices': [9, 5, 8, 6, 0, 3, 4, 2, 7, 10, 1], 'colors': [3, 2, 1]}
# Gen: 1 Wins: 15 Losses: 6
#
# Player 2 #8.7: Evolved Strategy #7: {'vertices': [0, 5, 8, 10, 2, 3, 6, 4, 1, 9, 7], 'colors': [2, 3, 1]}
# Gen: 15 Wins: 17 Losses: 1
# Player 2 #5.26: Evolved Strategy #26: {'vertices': [0, 5, 3, 6, 1, 10, 8, 7, 9, 2, 4], 'colors': [3, 2, 1]}
# Gen: 5 Wins: 70 Losses: 7
# Player 2 #5.33: Evolved Strategy #33: {'vertices': [0, 5, 3, 6, 1, 8, 2, 10, 7, 9, 4], 'colors': [3, 1, 2]}
# Gen: 13 Wins: 66 Losses: 7
# Player 2 #7.21: Evolved Strategy #21: {'vertices': [0, 5, 3, 2, 10, 7, 9, 8, 1, 6, 4], 'colors': [2, 3, 1]}
# Gen: 13 Wins: 37 Losses: 4
# Player 2 #7.31: Evolved Strategy #31: {'vertices': [0, 5, 3, 6, 1, 8, 7, 10, 9, 2, 4], 'colors': [3, 2, 1]}
# Gen: 16 Wins: 37 Losses: 4
# Player 2 #5.38: Evolved Strategy #38: {'vertices': [0, 5, 3, 6, 4, 1, 7, 2, 8, 10, 9], 'colors': [3, 1, 2]}
# Gen: 10 Wins: 78 Losses: 9
# Player 2 #6.1: Evolved Strategy #1: {'vertices': [0, 5, 3, 2, 10, 7, 9, 8, 1, 4, 6], 'colors': [1, 3, 2]}
# Gen: 6 Wins: 59 Losses: 7
# Player 2 #5.31: Evolved Strategy #31: {'vertices': [0, 8, 5, 3, 6, 1, 7, 10, 2, 4, 9], 'colors': [3, 2, 1]}
# Gen: 12 Wins: 67 Losses: 8
# Player 2 #5.6: Evolved Strategy #6: {'vertices': [5, 0, 3, 2, 10, 7, 9, 8, 1, 4, 6], 'colors': [3, 2, 1]}
# Gen: 5 Wins: 75 Losses: 9
# Player 2 #4.42: Evolved Strategy #42: {'vertices': [0, 5, 3, 6, 4, 1, 7, 2, 8, 10, 9], 'colors': [3, 1, 2]}
# Gen: 9 Wins: 90 Losses: 11
# Player 2 #6.15: Evolved Strategy #15: {'vertices': [0, 5, 3, 6, 1, 10, 8, 7, 9, 2, 4], 'colors': [3, 2, 1]}
# Gen: 10 Wins: 57 Losses: 7
# Player 2 #8.13: Evolved Strategy #13: {'vertices': [0, 5, 3, 1, 2, 10, 7, 9, 8, 6, 4], 'colors': [2, 3, 1]}
# Gen: 18 Wins: 16 Losses: 2
# Player 2 #5.44: Evolved Strategy #44: {'vertices': [0, 5, 3, 6, 1, 8, 7, 10, 2, 9, 4], 'colors': [3, 1, 2]}
# Gen: 7 Wins: 71 Losses: 9
# Player 2 #5.10: Evolved Strategy #10: {'vertices': [0, 5, 3, 6, 1, 8, 7, 10, 2, 4, 9], 'colors': [3, 2, 1]}
# Gen: 6 Wins: 70 Losses: 9
# Player 2 #5.51: Evolved Strategy #51: {'vertices': [0, 5, 3, 6, 1, 8, 7, 10, 9, 2, 4], 'colors': [3, 1, 2]}
# Gen: 11 Wins: 70 Losses: 9
# Player 2 #8.1: Evolved Strategy #1: {'vertices': [0, 5, 8, 3, 2, 10, 6, 1, 7, 9, 4], 'colors': [2, 3, 1]}
# Gen: 14 Wins: 15 Losses: 2
# Player 2 #6.4: Evolved Strategy #4: {'vertices': [0, 5, 3, 6, 4, 1, 7, 2, 8, 10, 9], 'colors': [3, 1, 2]}
# Gen: 10 Wins: 51 Losses: 7
# Player 2 #3.31: Evolved Strategy #31: {'vertices': [0, 5, 3, 6, 4, 1, 7, 2, 8, 10, 9], 'colors': [3, 1, 2]}
# Gen: 5 Wins: 108 Losses: 15
# Player 2 #7.34: Evolved Strategy #34: {'vertices': [0, 5, 3, 1, 2, 6, 8, 7, 10, 9, 4], 'colors': [3, 2, 1]}
# Gen: 16 Wins: 35 Losses: 5
# Player 2 #6.13: Evolved Strategy #13: {'vertices': [0, 5, 3, 2, 10, 7, 9, 8, 1, 6, 4], 'colors': [2, 3, 1]}
# Gen: 12 Wins: 54 Losses: 8
# Player 2 #6.35: Evolved Strategy #35: {'vertices': [0, 5, 3, 6, 1, 8, 7, 4, 2, 10, 9], 'colors': [3, 1, 2]}
# Gen: 11 Wins: 59 Losses: 9
# Player 2 #6.29: Evolved Strategy #29: {'vertices': [0, 5, 7, 3, 6, 1, 9, 8, 2, 4, 10], 'colors': [3, 2, 1]}
# Gen: 14 Wins: 45 Losses: 7
# Player 2 #7.8: Evolved Strategy #8: {'vertices': [0, 5, 3, 6, 1, 8, 7, 10, 9, 2, 4], 'colors': [3, 2, 1]}
# Gen: 14 Wins: 37 Losses: 6
# Player 2 #4.32: Evolved Strategy #32: {'vertices': [0, 5, 2, 8, 1, 10, 4, 7, 6, 3, 9], 'colors': [3, 1, 2]}
# Gen: 8 Wins: 80 Losses: 13
# Player 2 #5.45: Evolved Strategy #45: {'vertices': [0, 5, 3, 4, 1, 6, 10, 8, 2, 9, 7], 'colors': [3, 2, 1]}
# Gen: 12 Wins: 73 Losses: 12
# Player 2 #6.14: Evolved Strategy #14: {'vertices': [0, 5, 3, 6, 1, 8, 7, 10, 2, 9, 4], 'colors': [3, 2, 1]}
# Gen: 8 Wins: 54 Losses: 9
# Player 2 #6.32: Evolved Strategy #32: {'vertices': [0, 5, 3, 6, 1, 8, 7, 10, 2, 4, 9], 'colors': [3, 1, 2]}
# Gen: 14 Wins: 54 Losses: 9
# Player 2 #7.27: Evolved Strategy #27: {'vertices': [0, 5, 3, 6, 1, 8, 7, 10, 2, 9, 4], 'colors': [3, 2, 1]}
# Gen: 13 Wins: 30 Losses: 5
# Player 2 #7.4: Evolved Strategy #4: {'vertices': [0, 5, 3, 6, 1, 8, 7, 10, 9, 2, 4], 'colors': [3, 2, 1]}
# Gen: 9 Wins: 35 Losses: 6
# Player 2 #6.30: Evolved Strategy #30: {'vertices': [0, 5, 3, 1, 2, 6, 8, 7, 10, 9, 4], 'colors': [3, 1, 2]}
# Gen: 14 Wins: 52 Losses: 9
# Player 2 #4.3: Evolved Strategy #3: {'vertices': [0, 5, 3, 6, 1, 10, 8, 2, 4, 9, 7], 'colors': [3, 2, 1]}
# Gen: 4 Wins: 79 Losses: 14
# Player 2 #7.22: Evolved Strategy #22: {'vertices': [0, 5, 3, 2, 10, 7, 9, 8, 1, 4, 6], 'colors': [3, 2, 1]}
# Gen: 15 Wins: 28 Losses: 5
# Player 2 #7.37: Evolved Strategy #37: {'vertices': [0, 5, 3, 6, 4, 1, 7, 2, 8, 10, 9], 'colors': [3, 1, 2]}
# Gen: 13 Wins: 33 Losses: 6
# Player 2 #7.35: Evolved Strategy #35: {'vertices': [0, 5, 3, 2, 10, 7, 9, 8, 1, 4, 6], 'colors': [3, 2, 1]}
# Gen: 15 Wins: 32 Losses: 6
# Player 2 #7.29: Evolved Strategy #29: {'vertices': [0, 5, 3, 10, 2, 8, 6, 4, 1, 7, 9], 'colors': [3, 1, 2]}
# Gen: 15 Wins: 37 Losses: 7
# Player 2 #7.30: Evolved Strategy #30: {'vertices': [0, 5, 3, 6, 1, 8, 7, 2, 10, 9, 4], 'colors': [3, 2, 1]}
# Gen: 4 Wins: 42 Losses: 8
# Player 2 #4.51: Evolved Strategy #51: {'vertices': [8, 0, 5, 3, 2, 10, 7, 6, 1, 9, 4], 'colors': [3, 2, 1]}
# Gen: 11 Wins: 78 Losses: 15
# Player 2 #4.8: Evolved Strategy #8: {'vertices': [5, 0, 1, 2, 3, 6, 8, 7, 10, 9, 4], 'colors': [3, 2, 1]}
# Gen: 4 Wins: 91 Losses: 18
# Player 2 #6.2: Evolved Strategy #2: {'vertices': [0, 5, 3, 6, 4, 2, 8, 1, 10, 7, 9], 'colors': [3, 1, 2]}
# Gen: 11 Wins: 54 Losses: 11
# Player 2 #6.31: Evolved Strategy #31: {'vertices': [0, 10, 5, 2, 8, 3, 6, 4, 1, 7, 9], 'colors': [3, 1, 2]}
# Gen: 11 Wins: 44 Losses: 9
# Player 2 #7.24: Evolved Strategy #24: {'vertices': [0, 5, 3, 6, 4, 1, 10, 2, 8, 7, 9], 'colors': [3, 1, 2]}
# Gen: 13 Wins: 34 Losses: 7
# Player 2 #7.20: Evolved Strategy #20: {'vertices': [0, 5, 3, 2, 10, 7, 9, 8, 1, 4, 6], 'colors': [3, 2, 1]}
# Gen: 14 Wins: 29 Losses: 6
# Player 2 #7.25: Evolved Strategy #25: {'vertices': [0, 5, 3, 2, 10, 7, 9, 8, 6, 1, 4], 'colors': [3, 2, 1]}
# Gen: 14 Wins: 33 Losses: 7
# Player 2 #5.57: Evolved Strategy #57: {'vertices': [8, 0, 5, 3, 2, 10, 7, 6, 1, 9, 4], 'colors': [3, 2, 1]}
# Gen: 13 Wins: 74 Losses: 17
# Player 2 #7.15: Evolved Strategy #15: {'vertices': [8, 0, 5, 1, 2, 4, 9, 6, 7, 3, 10], 'colors': [3, 2, 1]}
# Gen: 16 Wins: 39 Losses: 9
# Player 2 #8.18: Evolved Strategy #18: {'vertices': [8, 0, 5, 1, 3, 6, 7, 10, 2, 9, 4], 'colors': [3, 2, 1]}
# Gen: 12 Wins: 13 Losses: 3
# Player 2 #7.23: Evolved Strategy #23: {'vertices': [0, 5, 3, 7, 6, 1, 9, 8, 2, 4, 10], 'colors': [3, 2, 1]}
# Gen: 15 Wins: 30 Losses: 7
# Player 2 #6.9: Evolved Strategy #9: {'vertices': [0, 5, 3, 4, 1, 6, 7, 2, 8, 10, 9], 'colors': [3, 2, 1]}
# Gen: 13 Wins: 51 Losses: 12
# Player 2 #5.22: Evolved Strategy #22: {'vertices': [5, 0, 3, 2, 10, 7, 9, 6, 1, 8, 4], 'colors': [3, 2, 1]}
# Gen: 9 Wins: 67 Losses: 16
# Player 2 #4.29: Evolved Strategy #29: {'vertices': [8, 0, 5, 1, 2, 4, 9, 6, 7, 3, 10], 'colors': [3, 2, 1]}
# Gen: 10 Wins: 83 Losses: 20
# Player 2 #4.44: Evolved Strategy #44: {'vertices': [0, 5, 3, 2, 10, 7, 9, 8, 1, 4, 6], 'colors': [2, 3, 1]}
# Gen: 11 Wins: 87 Losses: 21
# Player 2 #5.14: Evolved Strategy #14: {'vertices': [8, 0, 5, 3, 6, 1, 7, 10, 2, 4, 9], 'colors': [3, 2, 1]}
# Gen: 11 Wins: 69 Losses: 17
# Player 2 #7.2: Evolved Strategy #2: {'vertices': [0, 5, 3, 6, 1, 8, 2, 10, 7, 9, 4], 'colors': [3, 2, 1]}
# Gen: 15 Wins: 28 Losses: 7
# Player 2 #0.50: Evolved Strategy #50: {'vertices': [5, 0, 1, 2, 4, 9, 6, 7, 3, 10, 8], 'colors': [3, 2, 1]}
# Gen: 2 Wins: 143 Losses: 37
# Player 2 #2.24: Evolved Strategy #24: {'vertices': [0, 5, 3, 2, 10, 7, 9, 8, 1, 4, 6], 'colors': [2, 3, 1]}
# Gen: 4 Wins: 114 Losses: 30
# Player 2 #1.46: Evolved Strategy #46: {'vertices': [0, 5, 3, 6, 1, 8, 7, 10, 9, 2, 4], 'colors': [3, 1, 2]}
# Gen: 1 Wins: 120 Losses: 32
# Player 2 #5.9: Evolved Strategy #9: {'vertices': [5, 0, 1, 2, 3, 6, 8, 7, 10, 9, 4], 'colors': [3, 1, 2]}
# Gen: 6 Wins: 63 Losses: 17
# Player 2 #6.17: Evolved Strategy #17: {'vertices': [0, 5, 3, 2, 10, 7, 9, 8, 1, 4, 6], 'colors': [1, 2, 3]}
# Gen: 6 Wins: 48 Losses: 13
# Player 2 #4.23: Evolved Strategy #23: {'vertices': [0, 5, 3, 2, 10, 7, 9, 8, 1, 4, 6], 'colors': [2, 3, 1]}
# Gen: 5 Wins: 74 Losses: 21
# Player 2 #7.5: Evolved Strategy #5: {'vertices': [0, 5, 3, 6, 1, 10, 7, 9, 8, 2, 4], 'colors': [3, 2, 1]}
# Gen: 15 Wins: 28 Losses: 8
# Player 2 #7.9: Evolved Strategy #9: {'vertices': [0, 5, 3, 6, 1, 8, 7, 10, 9, 2, 4], 'colors': [3, 1, 2]}
# Gen: 12 Wins: 31 Losses: 9
# Player 2 #1.1: Evolved Strategy #1: {'vertices': [0, 5, 3, 6, 1, 2, 8, 10, 9, 4, 7], 'colors': [2, 3, 1]}
# Gen: 3 Wins: 125 Losses: 37
# Player 2 #5.29: Evolved Strategy #29: {'vertices': [5, 0, 1, 2, 3, 10, 7, 9, 8, 4, 6], 'colors': [3, 2, 1]}
# Gen: 7 Wins: 63 Losses: 19
# Player 2 #7.26: Evolved Strategy #26: {'vertices': [0, 5, 3, 2, 8, 1, 10, 4, 7, 9, 6], 'colors': [2, 3, 1]}
# Gen: 11 Wins: 26 Losses: 8
# Player 2 #6.16: Evolved Strategy #16: {'vertices': [5, 0, 1, 2, 3, 6, 8, 7, 10, 9, 4], 'colors': [3, 1, 2]}
# Gen: 8 Wins: 42 Losses: 13
# Player 2 #7.14: Evolved Strategy #14: {'vertices': [0, 5, 8, 3, 2, 10, 7, 6, 1, 9, 4], 'colors': [2, 3, 1]}
# Gen: 12 Wins: 31 Losses: 10
# Player 2 #7.16: Evolved Strategy #16: {'vertices': [5, 0, 1, 2, 3, 6, 8, 7, 10, 9, 4], 'colors': [3, 2, 1]}
# Gen: 14 Wins: 32 Losses: 11
# Player 2 #7.32: Evolved Strategy #32: {'vertices': [8, 0, 5, 1, 3, 6, 7, 10, 2, 9, 4], 'colors': [3, 2, 1]}
# Gen: 11 Wins: 32 Losses: 11
# Player 2 #8.21: Evolved Strategy #21: {'vertices': [0, 5, 3, 2, 10, 7, 9, 8, 1, 6, 4], 'colors': [3, 1, 2]}
# Gen: 13 Wins: 17 Losses: 6
# Player 2 #7.13: Evolved Strategy #13: {'vertices': [0, 5, 3, 2, 10, 7, 9, 8, 6, 1, 4], 'colors': [3, 2, 1]}
# Gen: 16 Wins: 31 Losses: 11
# Player 2 #5.55: Evolved Strategy #55: {'vertices': [0, 5, 3, 4, 10, 2, 8, 6, 7, 9, 1], 'colors': [1, 2, 3]}
# Gen: 12 Wins: 62 Losses: 22
# Player 2 #8.4: Evolved Strategy #4: {'vertices': [0, 5, 3, 1, 2, 6, 8, 7, 10, 9, 4], 'colors': [3, 2, 1]}
# Gen: 17 Wins: 14 Losses: 5
# Player 2 #5.32: Evolved Strategy #32: {'vertices': [8, 0, 5, 3, 2, 10, 7, 6, 1, 9, 4], 'colors': [3, 1, 2]}
# Gen: 12 Wins: 63 Losses: 23
# Player 2: Basic Data Strategy: {'vertices': [0, 5, 3, 6, 1, 8, 7, 10, 9, 2, 4], 'colors': [2, 1, 3]}
# Gen: 0 Wins: 133 Losses: 50
# Player 2 #6.5: Evolved Strategy #5: {'vertices': [5, 0, 3, 2, 10, 7, 9, 8, 6, 1, 4], 'colors': [3, 2, 1]}
# Gen: 13 Wins: 45 Losses: 17
